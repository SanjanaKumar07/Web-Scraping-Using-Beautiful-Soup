# %%
from urllib.request import urlopen

# %%
from bs4 import BeautifulSoup

# %%
html=urlopen("https://www.commandonetworks.com/switches/SF50-5")

# %%
bsObj=BeautifulSoup(html.read())
print(bsObj.prettify())
# Out:
# <!DOCTYPE html>
# <!--Conditionals for IE8-9 Support-->
# <!--[if IE]><html lang="en" class="ie"><![endif]-->
# <html>
#  <head>
#   <style>
#    .header {
#   position: fixed;
#   top: 0;
#   z-index: 1;
#   width: 100%;
#   background-color: #f1f1f1;
# }
#
# .progress-container {
#   width: 100%;
#  height: 4px;
#   background:transparent;
#  z-index: 9999;
# }
# #myBar{
#  height: 2px;
# }
#
# .progress-bar {
#   height: 2px;
#   background: #4caf50;
#   width: 0%;
# }
#
# .content {
#   padding: 100px 0;
#   margin: 50px auto 0 auto;
#   width: 80%;
# }
# .sticky {
#   position: fixed;
#   top: 0;
#   width: 100%;
# }
#
# .sticky + .content {
#   padding-top: 102px;
# }
#   </style>
#   <script>
#    // When the user scrolls the page, execute myFunction
#         window.onscroll = function() {myFunction()};
#         function myFunction()
#     {
#
#            var winScroll = document.body.scrollTop || document.documentElement.scrollTop;
#            var height = document.documentElement.scrollHeight - document.documentElement.clientHeight;
#            var scrolled = (winScroll / height) * 100;
#            document.getElementById("myBar").style.width = scrolled + "%";
#
#            var header = document.getElementById("Myheader");
#            var sticky = header.offsetTop;
#
#           if (window.pageYOffset > sticky)
#          {
#                 header.classList.add("sticky");
#              }
#      else
#        {
#               header.classList.remove("sticky");
#            }
#         }
#   </script>
#   <meta charset="utf-8"/>
#   <title>
#    COMMANDO | Network Switches &amp; Wireless Equipment | Switches | Managed L2 PoE Switches | Managed L2 Non-PoE Switches | Smart Unmanged PoE Switches | Smart Unmanaged Non-PoE Switches | Fiber Switch | Quality. Guaranteed. | One Year Warranty.
#   </title>
#   <!--SEO Meta Tags-->
#   <meta content="COMMANDO | Network Switches &amp; Wireless Equipment | Switches | Managed L2 PoE Switches | Managed L2 Non-PoE Switches | Smart Unmanged PoE Switches | Smart Unmanaged Non-PoE Switches | Fiber Switch | Quality. Guaranteed. | One Year Warranty." name="description"/>
#   <meta content="COMMANDO Marshall Switches, COMMANDO Soldier Switches, COMMANDO Scout Switches, COMMANDO Wireless Access Points, COMMANDO Wireless Bridge, COMMANDO AirONE Wireless, COMMANDO AirNET Wireless, COMMANDO AirACE Wireless, COMMANDO AirPRO Wireless, COMMANDO Media Converters, COMMANDO Transceivers, COMMANDO LightningPOWER PoE Injectors, COMMANDO AC/DC Adapters, COMMANDO SolidFIBER Fiber Cables, COMMANDO PureCABLE Network Cables" name="keywords"/>
#   <meta content="COMMANDO - Networking Hardware Company - Switches, Routers, Wireless, Indoor/Outdoor Access Points, Wireless Bridge, Wireless Antennas, Fiber Media Converters, SFP Transceivers, PoE Injectors, AC/DC Adapters, Fiber Optic Cables and Networking Accessories – Quality Guaranteed." name="classification"/>
#   <!--Mobile Specific Meta Tag-->
#   <meta content="width=device-width, initial-scale=1.0, maximum-scale=1.0, user-scalable=no" name="viewport"/>
#   <meta content="COMMANDO Networks" name="author"/>
#   <meta content="COMMANDO - Networking Hardware Company" name="subject"/>
#   <meta content="COMMANDO SF50 5FE, SOHO Unmanaged Switch" property="og:title"/>
#   <meta content="https://www.commandonetworks.com/" property="og:site_name"/>
#   <meta content="https://www.commandonetworks.com/assets/whatsapp/SF100-5P.jpg" property="og:image"/>
#   <meta content="website" property="og:type"/>
#   <meta content="https://www.commandonetworks.com/" property="og:url"/>
#   <!--<meta name="apple-itunes-app" content="app-id=1303499273">
#     <meta name="google-play-app" content="app-id=com.commandonetworks.commando">
# 	<link rel="stylesheet" href="https://www.commandonetworks.com//smartbanner2/jquery.smartbanner.css" type="text/css" media="screen">
#     <link rel="apple-touch-icon" href="https://www.commandonetworks.com/assets/img/apple-app-store-white.png" />
#     <link rel="android-touch-icon" href="https://www.commandonetworks.com/assets/img/google-play-store-white.png" />-->
#   <meta content="app-id=1303499273, affiliate-data=myAffiliateData, app-argument=https%3A%2F%2Fcommandonetworks.com" name="apple-itunes-app"/>
#   <meta content="app-id=com.commandonetworks.commando" name="google-play-app"/>
#   <!--<link rel="stylesheet" href="https://www.commandonetworks.com//smartbanner2/jquery.smartbanner.css" type="text/css" media="screen">-->
#   <link href="https://www.commandonetworks.com/assets/img/google-play-store-white.png" rel="android-touch-icon"/>
#   <link href="https://www.commandonetworks.com/assets/img/apple-app-store-white.png" rel="apple-touch-icon"/>
#   <link href="https://www.commandonetworks.com/smartappbanner/smart-app-banner.css" media="screen" rel="stylesheet" type="text/css"/>
#   <script src="https://www.commandonetworks.com/smartappbanner/smart-app-banner.js">
#   </script>
#   <script type="text/javascript">
#    new SmartBanner({
#           daysHidden: 3,   // days to hide banner after close button is clicked (defaults to 15)
#           daysReminder: 5, // days to hide banner after "VIEW" button is clicked (defaults to 90)
#           appStoreLanguage: 'us', // language code for the App Store (defaults to user's browser language)
#           title: 'Download App',
#           author: 'COMMANDO Networks',
#           button: 'OPEN',
#           store: {
#               ios: 'On the App Store',
#               android: 'In Google Play',
#               windows: 'In Windows store'
#           },
#           price: {
#               ios: 'FREE',
#               android: 'FREE',
#               windows: 'FREE'
#           }
#           , theme: 'android' // put platform type ('ios', 'android', etc.) here to force single theme on all device
#           // , icon: '' // full path to icon image if not using website icon image
#           // , force: 'ios' // Uncomment for platform emulation
#       });
#   </script>
#   <!--Favicon-->
#   <link href="https://www.commandonetworks.com/assets/img/favicon.png" rel="shortcut icon" type="image/png"/>
#   <!--Font Awesome 5 Pro -->
#   <link href="https://www.commandonetworks.com/assets/fontawesome5_Pro/pro.min.css" rel="stylesheet"/>
#   <!--Bootstrap4 -->
#   <link href="https://www.commandonetworks.com/assets/bootstrap4/css/bootstrap.css" rel="stylesheet"/>
#   <!--Master Slider Styles-->
#   <!--<link href="https://www.commandonetworks.com/assets/masterslider/style/masterslider.css" rel="stylesheet" media="screen">-->
#   <!--Stylesheet-->
#   <link href="https://www.commandonetworks.com/assets/css/styles.css" media="screen" rel="stylesheet"/>
#   <!--Banner Slider-->
#   <!--<link href="https://www.commandonetworks.com/assets/css/swiper.min.css" rel="stylesheet" media="screen">-->
#   <!--<link href="https://www.commandonetworks.com/assets/css/product-slider.css" rel="stylesheet" media="screen">-->
#   <!--Color Scheme-->
#   <link class="color-scheme" href="https://www.commandonetworks.com/assets/css/colors/color-2f8cea.css" media="screen" rel="stylesheet"/>
#   <!--Custom Scheme-->
#   <link href="https://www.commandonetworks.com/assets/css/custom.css" media="screen" rel="stylesheet"/>
#   <!--AOS Animation-->
#   <!--<link href="https://www.commandonetworks.com/assets/css/aos.css" rel="stylesheet">-->
#   <!--New Layout Design-->
#   <link href="https://www.commandonetworks.com/assets/css/new-layout-design.css" rel="stylesheet"/>
#   <link href="https://www.commandonetworks.com/assets/css/responsive.css" rel="stylesheet"/>
#   <!-- Menu CSS -->
#   <link class="color-scheme" href="https://www.commandonetworks.com/assets/css/header-with-menu1.css" media="screen" rel="stylesheet"/>
#   <!-- MENU CSS END -->
#   <!--Animation-->
#   <link href="https://www.commandonetworks.com/assets/css/animate.css" rel="stylesheet"/>
#   <!-- FORM CSS -->
#   <link href="https://www.commandonetworks.com/assets/css/formstyle.css" rel="stylesheet" type="text/css"/>
#   <!-- Magnific Popup CSS -->
#   <link href="https://www.commandonetworks.com/assets/css/magnific-popup.min.css" rel="stylesheet"/>
#   <!--Google Maps API-->
#   <!-- <script type="text/javascript" src="https://maps.googleapis.com/maps/api/js?key=AIzaSyA5DLwPPVAz88_k0yO2nmFe7T9k1urQs84"></script> -->
#   <!--Javascript (jQuery) Libraries and Plugins-->
#   <script src="https://www.commandonetworks.com/assets/js/libs/jquery-1.11.1.min.js">
#   </script>
#   <!--Modernizr-->
#   <script src="https://www.commandonetworks.com/assets/js/libs/modernizr.custom.js">
#   </script>
#   <!--Adding Media Queries Support for IE8-->
#   <!--[if lt IE 9]>
#       <script src="assets/js/plugins/respond.js"></script>
#     <![endif]-->
#   <!-- Global site tag (gtag.js) - Google Analytics -->
#   <script async="" src="https://www.googletagmanager.com/gtag/js?id=UA-151760676-1">
#   </script>
#   <!--Day Nidht -->
#   <link href="https://www.commandonetworks.com/assets/css/daynightmode.css" rel="stylesheet"/>
#   <script>
#    window.dataLayer = window.dataLayer || [];
#   function gtag(){dataLayer.push(arguments);}
#   gtag('js', new Date());
#
#   gtag('config', 'UA-151760676-1');
#   </script>
#  </head>
#  <!--Body-->
#  <body class="parallax animated fadeIn">
#   <!--Add "parallax" class if you have elements on the page with parallax backgrounds. "fadeIn" class makes content fades in on loading-->
#   <!--Off-Canvas-->
#   <div class="off-canvas-wrap" data-offcanvas="">
#    <div class="inner-wrap">
#     <!--Layout-->
#     <div class="site-layout">
#      <!--If you add class "boxed" to .site-layout it wraps the whole document in a box, than you can simply add pattern background to body or leave it white. Please note in a "boxed" mode header doesn't stick to the top.-->
#      <!--Header-->
#      <div class="public_mask">
#      </div>
#      <!--scroll progress bar-->
#      <div class="progress-container" id="Myheader">
#       <div class="progress-bar" id="myBar">
#       </div>
#      </div>
#      <section class="head mobile_head">
#       <div class="container-fluid">
#        <div class="new_p_box_1420">
#         <div class="col-lg-2 col-sm-4 left_box">
#          <div class="row">
#           <!-- Mobile Menu -->
#           <div class="mobile_menu_list close_side d-lg-none">
#            <span class="line">
#            </span>
#            <span class="line">
#            </span>
#            <span class="line">
#            </span>
#           </div>
#           <a class="header_logo" href="https://www.commandonetworks.com/">
#            <img alt="" src="https://www.commandonetworks.com/assets/img/logo1.png"/>
#           </a>
#          </div>
#         </div>
#         <div class="col-lg-10 col-sm-8 right_box">
#          <div class="row">
#           <div class="col-lg-12 right_box_top">
#            <div class="top_menu">
#             <div class="country_sele">
#              <div class="changeCountry">
#               <span class="country_sele_flag us first">
#               </span>
#               <span class="country_sele_language">
#                English
#               </span>
#               <span class="country_sele_arrow fal fa-chevron-down down_arrow">
#               </span>
#              </div>
#              <div class="country_sele_more">
#               <div class="header_sign_more_arrow">
#               </div>
#               <div class="country_sele_more_main">
#                <h3 class="country_sele_more_main_title">
#                 Select Language
#                </h3>
#                <!--<div class="country_sele_choose_country">
# 														<em id="current_code" data-class="country_code" class="us"></em>
# 														<p class="country_name" translate="no" lang="en">English</p>
# 													</div>-->
#                <div class="country_sele_searchCountry" style=" display:block;">
#                 <div class="country_sele_search_block">
#                  <input class="country_sele_search_input" placeholder="Search your country/region" type="text"/>
#                 </div>
#                 <ul class="country_sele_countryList">
#                  <div id="ytWidget">
#                  </div>
#                  <script src="https://www.commandonetworks.com/language/lang.js" type="text/javascript">
#                  </script>
#                 </ul>
#                </div>
#               </div>
#              </div>
#             </div>
#             <!--<div class="mid_line"></div>
# 										<div class="flag">
# 																						<!--<img src="https://www.commandonetworks.com/assets/img/flags-mini/.png"/>
# 											<span class="flag_font"></span>
# 											<span class="flag_icon"><i class="fal fa-angle-down"></i></span>-->
#             <!--<i class="fal fa-globe d-sm-none d-md-block"></i>--
# 											<div id="ytWidget"></div>
# 											<script src="https://www.commandonetworks.com/language/lang.js" type="text/javascript"></script>
# 										</div>-->
#             <div class="mid_line">
#             </div>
#             <div class="noti not_active">
#              <svg viewbox="-10 0 35 35">
#               <path class="notification--bell" d="M14 12v1H0v-1l0.73-0.58c0.77-0.77 0.81-3.55 1.19-4.42 0.77-3.77 4.08-5 4.08-5 0-0.55 0.45-1 1-1s1 0.45 1 1c0 0 3.39 1.23 4.16 5 0.38 1.88 0.42 3.66 1.19 4.42l0.66 0.58z">
#               </path>
#               <path class="notification--bellClapper" d="M7 15.7c1.11 0 2-0.89 2-2H5c0 1.11 0.89 2 2 2z">
#               </path>
#              </svg>
#              <span class="notification--num">
#               3
#              </span>
#              <div class="header_noti_more">
#               <div class="header_noti_more_arrow">
#               </div>
#               <div class="header_noti_more_main">
#                <div class="hreder_wrapp">
#                 <!--<p><img src="https://www.commandonetworks.com/assets/img/broadcast-test.jpg"></p>-->
#                 <p>
#                  No Notification
#                 </p>
#                </div>
#               </div>
#              </div>
#             </div>
#             <div class="mid_line">
#             </div>
#             <div class="signin">
#              <a class="signin_a" href="#">
#               <i class="fal fa-user-lock">
#               </i>
#              </a>
#              <div class="header_sign_more">
#               <div class="header_sign_more_arrow">
#               </div>
#               <div class="header_sign_more_main">
#                <div class="hreder_wrapp">
#                 <a class="header_sign_more_main_sign" href="https://www.commandonetworks.com/partnerlogin" target="_blank">
#                  <span class="header_signTxt">
#                   Sign in
#                  </span>
#                  <div class="loader_order">
#                   <svg class="circular" viewbox="25 25 50 50">
#                    <circle class="path" cx="50" cy="50" fill="none" r="20" stroke-miterlimit="10" stroke-width="4">
#                    </circle>
#                   </svg>
#                  </div>
#                 </a>
#                 <p class="header_sign_more_main_register">
#                  Dont have account?
#                  <a href="apply" target="_blank">
#                   Sign Up
#                  </a>
#                 </p>
#                </div>
#               </div>
#              </div>
#             </div>
#             <div class="mid_line d-sm-none d-lg-block">
#             </div>
#             <div class="top_help d-sm-none d-lg-block">
#              <a href="#">
#               <i class="fal fa-clipboard-list icon">
#               </i>
#               <span class="top_help_font">
#                RFQ
#               </span>
#              </a>
#              <div class="header_help_more">
#               <div class="header_sign_more_arrow" style="right: 33.5547px;">
#               </div>
#               <div class="header_help_more_main">
#                <div class="header_help_more_main_con">
#                 <a href="https://www.commandonetworks.com/rfq/switches" target="_blank">
#                  <img src="https://www.commandonetworks.com/assets/img/home_category_icon/sw.png"/>
#                  <h2 class="header_help_more_main_con_tit">
#                   Switches
#                  </h2>
#                 </a>
#                </div>
#                <!--<div class="header_help_more_main_con">
# 														<a href="https://www.commandonetworks.com/rfq/routers" target="_blank">
# 															<img src="https://www.commandonetworks.com/assets/img/home_category_icon/ap.png"/>
# 															<h2 class="header_help_more_main_con_tit">Routers</h2>
# 														</a>
# 													</div>-->
#                <div class="header_help_more_main_con">
#                 <a href="https://www.commandonetworks.com/rfq/wireless" target="_blank">
#                  <img src="https://www.commandonetworks.com/assets/img/home_category_icon/wr.png"/>
#                  <h2 class="header_help_more_main_con_tit">
#                   Wireless
#                  </h2>
#                 </a>
#                </div>
#                <div class="header_help_more_main_con">
#                 <a href="https://www.commandonetworks.com/rfq/converters" target="_blank">
#                  <img src="https://www.commandonetworks.com/assets/img/home_category_icon/mc.png"/>
#                  <h2 class="header_help_more_main_con_tit">
#                   Media Converters
#                  </h2>
#                 </a>
#                </div>
#                <div class="header_help_more_main_con">
#                 <a href="https://www.commandonetworks.com/rfq/transceivers" target="_blank">
#                  <img src="https://www.commandonetworks.com/assets/img/home_category_icon/tr.png"/>
#                  <h2 class="header_help_more_main_con_tit">
#                   Transceivers
#                  </h2>
#                 </a>
#                </div>
#                <div class="header_help_more_main_con">
#                 <a href="https://www.commandonetworks.com/rfq/injectors" target="_blank">
#                  <img src="https://www.commandonetworks.com/assets/img/home_category_icon/in.png"/>
#                  <h2 class="header_help_more_main_con_tit">
#                   PoE Injectors
#                  </h2>
#                 </a>
#                </div>
#                <!-- <div class="header_help_more_main_con">
# 														<a href="https://www.commandonetworks.com/rfq/accessories" target="_blank">
# 															<img src="https://www.commandonetworks.com/assets/img/home_category_icon/fc.png"/>
# 															<h2 class="header_help_more_main_con_tit">Accessories</h2>
# 														</a>
# 													</div> -->
#                <div class="header_help_more_main_con">
#                 <a href="https://www.commandonetworks.com/rfq" target="_blank">
#                  <img src="https://www.commandonetworks.com/assets/img/home_category_icon/all.png"/>
#                  <h2 class="header_help_more_main_con_tit">
#                   All Products
#                  </h2>
#                 </a>
#                </div>
#               </div>
#              </div>
#             </div>
#             <div class="mid_line d-sm-none d-lg-block">
#             </div>
#             <div class="top_help d-sm-none d-lg-block">
#              <a href="#">
#               <i class="fal fa-user-friends icon">
#               </i>
#               <span class="top_help_font">
#                Partner
#               </span>
#              </a>
#              <div class="header_help_more">
#               <div class="header_sign_more_arrow" style="right: 33.5547px;">
#               </div>
#               <div class="header_help_more_main">
#                <div class="header_help_more_main_con">
#                 <a href="https://www.commandonetworks.com/partnerprogram" target="_blank">
#                  <i class="fal fa-user-cog icon">
#                  </i>
#                  <h2 class="header_help_more_main_con_tit">
#                   Partner Program
#                  </h2>
#                 </a>
#                </div>
#                <div class="header_help_more_main_con">
#                 <a href="https://www.commandonetworks.com/partneradvantage" target="_blank">
#                  <i class="fal fa-user-chart icon">
#                  </i>
#                  <h2 class="header_help_more_main_con_tit">
#                   Partner Advantage
#                  </h2>
#                 </a>
#                </div>
#                <div class="header_help_more_main_con">
#                 <a href="https://www.commandonetworks.com/apply" target="_blank">
#                  <i class="fal fa-poll-people icon">
#                  </i>
#                  <h2 class="header_help_more_main_con_tit">
#                   Partner Application
#                  </h2>
#                 </a>
#                </div>
#                <div class="header_help_more_main_con">
#                 <a href="https://www.commandonetworks.com/partnerlogin" target="_blank">
#                  <i class="fal fa-user-lock icon">
#                  </i>
#                  <h2 class="header_help_more_main_con_tit">
#                   Partner Login
#                  </h2>
#                 </a>
#                </div>
#               </div>
#              </div>
#             </div>
#             <div class="mid_line d-sm-none d-lg-block">
#             </div>
#             <div class="top_help d-sm-none d-lg-block">
#              <a href="#">
#               <i class="fal fa-building icon">
#               </i>
#               <span class="top_help_font">
#                Company
#               </span>
#              </a>
#              <div class="header_help_more">
#               <div class="header_sign_more_arrow" style="right: 33.5547px;">
#               </div>
#               <div class="header_help_more_main">
#                <div class="header_help_more_main_con">
#                 <a href="https://www.commandonetworks.com/profile" target="_blank">
#                  <i class="fal fa-user-friends icon">
#                  </i>
#                  <h2 class="header_help_more_main_con_tit">
#                   Company Profile
#                  </h2>
#                 </a>
#                </div>
#                <div class="header_help_more_main_con">
#                 <a href="https://www.commandonetworks.com/contactus" target="_blank">
#                  <i class="fal fa-phone-alt icon">
#                  </i>
#                  <h2 class="header_help_more_main_con_tit">
#                   Contact Us
#                  </h2>
#                 </a>
#                </div>
#                <div class="header_help_more_main_con">
#                 <a href="#">
#                  <i class="fal fa-blog icon">
#                  </i>
#                  <h2 class="header_help_more_main_con_tit">
#                   Blog
#                  </h2>
#                 </a>
#                </div>
#                <div class="header_help_more_main_con">
#                 <a href="https://www.commandonetworks.com/search" target="_blank">
#                  <i class="fal fa-file-search icon">
#                  </i>
#                  <h2 class="header_help_more_main_con_tit">
#                   Bulk Product Search
#                  </h2>
#                 </a>
#                </div>
#                <div class="header_help_more_main_con">
#                 <a href="https://www.commandonetworks.com/support/TechnicalSupport" target="_blank">
#                  <i class="fal fa-headset icon">
#                  </i>
#                  <h2 class="header_help_more_main_con_tit">
#                   Technical Support
#                  </h2>
#                 </a>
#                </div>
#                <div class="header_help_more_main_con">
#                 <a href="https://www.commandonetworks.com/support/SalesSupport" target="_blank">
#                  <i class="fal fa-handshake icon">
#                  </i>
#                  <h2 class="header_help_more_main_con_tit">
#                   Sales Support
#                  </h2>
#                 </a>
#                </div>
#               </div>
#              </div>
#             </div>
#             <div class="mid_line d-sm-none d-lg-block">
#             </div>
#             <!-- Desktop Search -->
#             <div class="header_main_search">
#              <i class="fal fa-times-circle aron_barry_clear_input">
#              </i>
#              <form action="https://www.commandonetworks.com/search/single_search_result" class="" id="desc-search" method="get" name="search" onsubmit="return hsValidate()" required="" style="padding:0;">
#               <input autocomplete="off" class="header_main_search_txt" id="CityAjax" name="search" placeholder="Search..." type="text" value=""/>
#               <input class="header_main_search_btn fal fa-search" name="searchSubmit" type="submit" value=""/>
#              </form>
#             </div>
#             <!-- Mobile Search -->
#             <span class="mobile_search d-lg-none">
#              <a href="https://www.commandonetworks.com/productsearch">
#               <i class="fal fa-search">
#               </i>
#              </a>
#             </span>
#             <div class="mid_line">
#             </div>
#             <div class="dyaNight">
#              <svg class="svg-icon switchMode ddark" viewbox="0 0 20 20">
#               <path d="M10.544,8.717l1.166-0.855l1.166,0.855l-0.467-1.399l1.012-0.778h-1.244L11.71,5.297l-0.466,1.244H10l1.011,0.778L10.544,8.717z M15.986,9.572l-0.467,1.244h-1.244l1.011,0.777l-0.467,1.4l1.167-0.855l1.165,0.855l-0.466-1.4l1.011-0.777h-1.244L15.986,9.572z M7.007,6.552c0-2.259,0.795-4.33,2.117-5.955C4.34,1.042,0.594,5.07,0.594,9.98c0,5.207,4.211,9.426,9.406,9.426c2.94,0,5.972-1.354,7.696-3.472c-0.289,0.026-0.987,0.044-1.283,0.044C11.219,15.979,7.007,11.759,7.007,6.552 M10,18.55c-4.715,0-8.551-3.845-8.551-8.57c0-3.783,2.407-6.999,5.842-8.131C6.549,3.295,6.152,4.911,6.152,6.552c0,5.368,4.125,9.788,9.365,10.245C13.972,17.893,11.973,18.55,10,18.55 M19.406,2.304h-1.71l-0.642-1.71l-0.642,1.71h-1.71l1.39,1.069l-0.642,1.924l1.604-1.176l1.604,1.176l-0.642-1.924L19.406,2.304z">
#               </path>
#              </svg>
#              <svg class="svg-icon switchMode dlight" style="display:none" viewbox="0 0 20 20">
#               <path d="M5.114,5.726c0.169,0.168,0.442,0.168,0.611,0c0.168-0.169,0.168-0.442,0-0.61L3.893,3.282c-0.168-0.168-0.442-0.168-0.61,0c-0.169,0.169-0.169,0.442,0,0.611L5.114,5.726z M3.955,10c0-0.239-0.193-0.432-0.432-0.432H0.932C0.693,9.568,0.5,9.761,0.5,10s0.193,0.432,0.432,0.432h2.591C3.761,10.432,3.955,10.239,3.955,10 M10,3.955c0.238,0,0.432-0.193,0.432-0.432v-2.59C10.432,0.693,10.238,0.5,10,0.5S9.568,0.693,9.568,0.932v2.59C9.568,3.762,9.762,3.955,10,3.955 M14.886,5.726l1.832-1.833c0.169-0.168,0.169-0.442,0-0.611c-0.169-0.168-0.442-0.168-0.61,0l-1.833,1.833c-0.169,0.168-0.169,0.441,0,0.61C14.443,5.894,14.717,5.894,14.886,5.726 M5.114,14.274l-1.832,1.833c-0.169,0.168-0.169,0.441,0,0.61c0.168,0.169,0.442,0.169,0.61,0l1.833-1.832c0.168-0.169,0.168-0.442,0-0.611C5.557,14.106,5.283,14.106,5.114,14.274 M19.068,9.568h-2.591c-0.238,0-0.433,0.193-0.433,0.432s0.194,0.432,0.433,0.432h2.591c0.238,0,0.432-0.193,0.432-0.432S19.307,9.568,19.068,9.568 M14.886,14.274c-0.169-0.168-0.442-0.168-0.611,0c-0.169,0.169-0.169,0.442,0,0.611l1.833,1.832c0.168,0.169,0.441,0.169,0.61,0s0.169-0.442,0-0.61L14.886,14.274z M10,4.818c-2.861,0-5.182,2.32-5.182,5.182c0,2.862,2.321,5.182,5.182,5.182s5.182-2.319,5.182-5.182C15.182,7.139,12.861,4.818,10,4.818M10,14.318c-2.385,0-4.318-1.934-4.318-4.318c0-2.385,1.933-4.318,4.318-4.318c2.386,0,4.318,1.933,4.318,4.318C14.318,12.385,12.386,14.318,10,14.318 M10,16.045c-0.238,0-0.432,0.193-0.432,0.433v2.591c0,0.238,0.194,0.432,0.432,0.432s0.432-0.193,0.432-0.432v-2.591C10.432,16.238,10.238,16.045,10,16.045">
#               </path>
#              </svg>
#             </div>
#            </div>
#           </div>
#           <div class="col-lg-12 right_box_bottom">
#            <span id="desktop_menu">
#             <!-- Desktop Menu -->
#             <ul class="header_main_ul">
#              <li class="header_main_list header_main_list_first">
#               <a href="#">
#                All Products
#               </a>
#              </li>
#              <li class="header_main_list header_main_list_first pc-alone-height">
#               <a href="https://www.commandonetworks.com/switches" target="_blank">
#                Switches
#               </a>
#              </li>
#              <!--<li class="header_main_list header_main_list_first pc-alone-height"><a href="https://www.commandonetworks.com/routers"  target="_blank">Routers</a></li>-->
#              <li class="header_main_list header_main_list_first pc-alone-height">
#               <a href="https://www.commandonetworks.com/wireless" target="_blank">
#                Wireless
#               </a>
#              </li>
#              <li class="header_main_list header_main_list_first pc-alone-height">
#               <a href="https://www.commandonetworks.com/converters" target="_blank">
#                Media Converters
#               </a>
#              </li>
#              <li class="header_main_list header_main_list_first pc-alone-height">
#               <a href="https://www.commandonetworks.com/transceivers" target="_blank">
#                Transceivers
#               </a>
#              </li>
#              <li class="header_main_list header_main_list_first pc-alone-height">
#               <a href="https://www.commandonetworks.com/injectors" target="_blank">
#                PoE Injectors
#               </a>
#              </li>
#              <!--<li class="header_main_list header_main_list_first pc-alone-height"><a href="https://www.commandonetworks.com/accessories"  target="_blank">Accessories</a></li>-->
#              <i class="header_sign_more_arrow pc-header_sign_more_arrow" style="left: 501.883px;">
#              </i>
#             </ul>
#             <div class="header_main_list_outer">
#              <div class="header_main_list_more outerbox">
#               <div class="header_main_list_more_outerbox_main">
#                <ul class="header_list_more_ul">
#                 <li>
#                  <a class="menu_popout_head_a" href="https://www.commandonetworks.com/switches" target="_blank">
#                   Switches
#                  </a>
#                  <div class="header_list_more_ul_main show">
#                   <div class="header_list_more_ul_main_all">
#                    <dl class="header_list_more_ul_main_all_con">
#                     <dt>
#                      <img src="https://www.commandonetworks.com/assets/images/menu/switches/C3500.png"/>
#                     </dt>
#                     <dd>
#                      <h2>
#                       <a href="https://www.commandonetworks.com/switches/Marshal_Switch_C3500" target="_blank">
#                        Marshall C3500 Series Modular Core Switches
#                       </a>
#                      </h2>
#                     </dd>
#                    </dl>
#                    <dl class="header_list_more_ul_main_all_con">
#                     <dt>
#                      <img src="https://www.commandonetworks.com/assets/images/menu/switches/C3000.png"/>
#                     </dt>
#                     <dd>
#                      <h2>
#                       <a href="https://www.commandonetworks.com/switches/Soldier_Switch_C3000" target="_blank">
#                        Soldier C3000 Series Modular Managed Switches
#                       </a>
#                      </h2>
#                     </dd>
#                    </dl>
#                    <!-- <dl class="header_list_more_ul_main_all_con"><dt><img src="https://www.commandonetworks.com/assets/images/menu/switches/C3000.png" /></dt>
# 								<dd>
# 									<h2><a href="https://www.commandonetworks.com/switches/Admiral_Switch_C3000" target="_blank">Admiral C3000 Series Modular Managed Switches</a></h2>
# 								</dd>
# 							</dl> -->
#                    <!--
# 							<dl class="header_list_more_ul_main_all_con"><dt><img src="https://www.commandonetworks.com/assets/images/menu/switches/IE3000.png" /></dt>
# 								<dd>
# 									<h2>
# 										<a href="https://www.commandonetworks.com/switches/Marshal_Switch_IE3000" target="_blank">
# 											Admiral IE3000 Series Modular Industrial Ethernet Managed Switches
# 										</a>
# 									</h2>
# 								</dd>
# 							</dl>-->
#                    <!-- <dl class="header_list_more_ul_main_all_con"><dt><img src="https://www.commandonetworks.com/assets/images/menu/switches/C2000.png" /></dt>
# 								<dd>
# 									<h2>
# 										<a href="https://www.commandonetworks.com/switches/Soldier_Switch_C2500" target="_blank">
# 											Soldier C2500 Series Modular Switches
# 										</a>
# 									</h2>
# 								</dd>
# 							</dl> -->
#                    <dl class="header_list_more_ul_main_all_con">
#                     <dt>
#                      <img src="https://www.commandonetworks.com/assets/images/menu/switches/IE2000.png"/>
#                     </dt>
#                     <dd>
#                      <h2>
#                       <a href="https://www.commandonetworks.com/switches/Soldier_Switch_IE2000" target="_blank">
#                        Soldier IE2000 Series Industrial Ethernet Managed Switches
#                       </a>
#                      </h2>
#                     </dd>
#                    </dl>
#                    <div class="clearfx">
#                    </div>
#                    <dl class="header_list_more_ul_main_all_con">
#                     <dt>
#                      <img src="https://www.commandonetworks.com/assets/images/menu/switches/C2000.png"/>
#                     </dt>
#                     <dd>
#                      <h2>
#                       <a href="https://www.commandonetworks.com/switches/Soldier_Switch_C2000" target="_blank">
#                        Soldier C2000 Series Managed Switches
#                       </a>
#                      </h2>
#                     </dd>
#                    </dl>
#                    <dl class="header_list_more_ul_main_all_con">
#                     <dt>
#                      <img src="https://www.commandonetworks.com/assets/images/menu/switches/E2000.png"/>
#                     </dt>
#                     <dd>
#                      <h2>
#                       <a href="https://www.commandonetworks.com/switches/Soldier_Switch_E2000" target="_blank">
#                        Soldier E2000 Series Managed Switches
#                       </a>
#                      </h2>
#                     </dd>
#                    </dl>
#                    <!--<dl class="header_list_more_ul_main_all_con"><dt><img src="https://www.commandonetworks.com/assets/images/menu/switches/E1500_LR.png" /></dt>
# 								<dd>
# 									<h2>
# 										<a href="https://www.commandonetworks.com/switches/Comrade_Switch_E1500_LR" target="_blank">
# 											Comrade E1500 Series Long Range Web Managed Switches
# 										</a>
# 									</h2>
# 								</dd>
# 							</dl>
# 							<dl class="header_list_more_ul_main_all_con"><dt><img src="https://www.commandonetworks.com/assets/images/menu/switches/E1500.png" /></dt>
# 								<dd>
# 									<h2>
# 										<a href="https://www.commandonetworks.com/switches/Comrade_Switch_E1500" target="_blank">
# 											Comrade E1500 Series Web Managed Switches
# 										</a>
# 									</h2>
# 								</dd>
# 							</dl>-->
#                    <dl class="header_list_more_ul_main_all_con">
#                     <dt>
#                      <img src="https://www.commandonetworks.com/assets/images/menu/switches/IE1000.png"/>
#                     </dt>
#                     <dd>
#                      <h2>
#                       <a href="https://www.commandonetworks.com/switches/Scout_Switch_IE1000" target="_blank">
#                        Scout IE1000 Series Industrial Ethernet Switches
#                       </a>
#                      </h2>
#                     </dd>
#                    </dl>
#                    <div class="clearfx">
#                    </div>
#                    <dl class="header_list_more_ul_main_all_con">
#                     <dt>
#                      <img src="https://www.commandonetworks.com/assets/images/menu/switches/C1000_BT.png"/>
#                     </dt>
#                     <dd>
#                      <h2>
#                       <a href="https://www.commandonetworks.com/switches/Scout_Switch_C1000_BT" target="_blank">
#                        Scout C1000 Series Ultra Power Switches
#                       </a>
#                      </h2>
#                     </dd>
#                    </dl>
#                    <dl class="header_list_more_ul_main_all_con">
#                     <dt>
#                      <img src="https://www.commandonetworks.com/assets/images/menu/switches/C1000.png"/>
#                     </dt>
#                     <dd>
#                      <h2>
#                       <a href="https://www.commandonetworks.com/switches/Scout_Switch_C1000" target="_blank">
#                        Scout C1000 Series Smart Switches
#                       </a>
#                      </h2>
#                     </dd>
#                    </dl>
#                    <dl class="header_list_more_ul_main_all_con">
#                     <dt>
#                      <img src="https://www.commandonetworks.com/assets/images/menu/switches/E1000_LR.png"/>
#                     </dt>
#                     <dd>
#                      <h2>
#                       <a href="https://www.commandonetworks.com/switches/Scout_Switch_E1000_LR" target="_blank">
#                        Scout E1000 Series Long Range Switches
#                       </a>
#                      </h2>
#                     </dd>
#                    </dl>
#                    <div class="clearfx">
#                    </div>
#                    <dl class="header_list_more_ul_main_all_con">
#                     <dt>
#                      <img src="https://www.commandonetworks.com/assets/images/menu/switches/E1000.png"/>
#                     </dt>
#                     <dd>
#                      <h2>
#                       <a href="https://www.commandonetworks.com/switches/Scout_Switch_E1000" target="_blank">
#                        Scout E1000 Series Smart Switches
#                       </a>
#                      </h2>
#                     </dd>
#                    </dl>
#                    <dl class="header_list_more_ul_main_all_con">
#                     <dt>
#                      <img src="https://www.commandonetworks.com/assets/images/menu/switches/E300.png"/>
#                     </dt>
#                     <dd>
#                      <h2>
#                       <a href="https://www.commandonetworks.com/switches/Scout_Switch_E300" target="_blank">
#                        Scout E300 Series Smart Switches
#                       </a>
#                      </h2>
#                     </dd>
#                    </dl>
#                    <dl class="header_list_more_ul_main_all_con">
#                     <dt>
#                      <img src="https://www.commandonetworks.com/assets/images/menu/switches/E100.png"/>
#                     </dt>
#                     <dd>
#                      <h2>
#                       <a href="https://www.commandonetworks.com/switches/Scout_Switch_E100" target="_blank">
#                        Scout E100 Series Smart Switches
#                       </a>
#                      </h2>
#                     </dd>
#                    </dl>
#                    <div class="clearfx">
#                    </div>
#                    <dl class="header_list_more_ul_main_all_con">
#                     <dt>
#                      <img src="https://www.commandonetworks.com/assets/images/menu/switches/SF_SG.png"/>
#                     </dt>
#                     <dd>
#                      <h2>
#                       <a href="https://www.commandonetworks.com/switches/SF_SG_Switch" target="_blank">
#                        SF/SG Series Smart Switches
#                       </a>
#                      </h2>
#                     </dd>
#                    </dl>
#                    <div class="clearfx">
#                    </div>
#                   </div>
#                  </div>
#                 </li>
#                 <!--<li><a href="https://www.commandonetworks.com/routers"  target="_blank" class="menu_popout_head_a">Routers</a>
# 					<div class="header_list_more_ul_main">
# 						<div class="header_list_more_ul_main_all">
# 							<dl class="header_list_more_ul_main_all_con"><dt><img src="https://www.commandonetworks.com/assets/img/home_category/routers/Wireless-Router.jpg" /></dt>
# 								<dd>
# 									<h2><a href="https://www.commandonetworks.com/routers/Wireless_Router">Wireless Routers</a></h2>
# 									<p><a href="https://www.commandonetworks.com/routers/Wireless_Router" target="_blank">Dual Band 802.11ac</a></p>
# 								</dd>
# 							</dl>
# 							<dl class="header_list_more_ul_main_all_con"><dt><img src="https://www.commandonetworks.com/assets/img/home_category/routers/Router.jpg" /></dt>
# 								<dd>
# 									<h2><a href="https://www.commandonetworks.com/routers/Enterprise_Router">Routers</a></h2>
# 									<p><a href="https://www.commandonetworks.com/routers/Enterprise_Router" target="_blank">Enterprise Router</a></p>
# 								</dd>
# 							</dl>
# 							<div class="clearfx"></div>
# 						</div>
# 					</div>
# 				</li>-->
#                 <li>
#                  <a class="menu_popout_head_a" href="https://www.commandonetworks.com/wireless" target="_blank">
#                   Wireless
#                  </a>
#                  <div class="header_list_more_ul_main">
#                   <div class="header_list_more_ul_main_all">
#                    <dl class="header_list_more_ul_main_all_con">
#                     <dt>
#                      <img src="https://www.commandonetworks.com/assets/img/home_category/wireless/indoor.png"/>
#                     </dt>
#                     <dd>
#                      <h2>
#                       <a href="https://www.commandonetworks.com/wireless/Indoor_Access_Points" target="_blank">
#                        Indoor Access Points
#                       </a>
#                      </h2>
#                      <p>
#                       <a href="https://www.commandonetworks.com/wireless/Indoor_Access_Points_24GHz80211n" target="_blank">
#                        2.4GHz 802.11n
#                       </a>
#                      </p>
#                      <p>
#                       <a href="https://www.commandonetworks.com/wireless/Indoor_Access_Points_24GHz5GHz80211ac" target="_blank">
#                        2.4GHz+5GHz 802.11ac
#                       </a>
#                      </p>
#                      <p>
#                       <a href="https://www.commandonetworks.com/wireless/Indoor_Access_Points_TriBand" target="_blank">
#                        Tri-Band
#                       </a>
#                      </p>
#                      <!--<p><a href="#">MIMO</a></p>
# 									<p><a href="#">MU-MIMO</a></p>-->
#                      <p>
#                       <a href="https://www.commandonetworks.com/wireless/Indoor_Access_Points" target="_blank">
#                        All Indoor Access Points
#                       </a>
#                      </p>
#                     </dd>
#                    </dl>
#                    <dl class="header_list_more_ul_main_all_con">
#                     <dt>
#                      <img src="https://www.commandonetworks.com/assets/img/home_category/wireless/outdoor.png"/>
#                     </dt>
#                     <dd>
#                      <h2>
#                       <a href="https://www.commandonetworks.com/wireless/Outdoor_Access_Points" target="_blank">
#                        Outdoor Access Points
#                       </a>
#                      </h2>
#                      <p>
#                       <a href="https://www.commandonetworks.com/wireless/Outdoor_Access_Points_24GHz80211n" target="_blank">
#                        2.4GHz 802.11n
#                       </a>
#                      </p>
#                      <p>
#                       <a href="https://www.commandonetworks.com/wireless/Outdoor_Access_Points_24GHz5GHz80211ac" target="_blank">
#                        2.4GHz+5GHz 802.11ac
#                       </a>
#                      </p>
#                      <p>
#                       <a href="https://www.commandonetworks.com/wireless/Outdoor_Access_Points" target="_blank">
#                        All Outdoor Access Points
#                       </a>
#                      </p>
#                     </dd>
#                    </dl>
#                    <dl class="header_list_more_ul_main_all_con">
#                     <dt>
#                      <img src="https://www.commandonetworks.com/assets/img/home_category/wireless/wirelessbridge.png"/>
#                     </dt>
#                     <dd>
#                      <h2>
#                       <a href="https://www.commandonetworks.com/wireless/Wireless_Bridge" target="_blank">
#                        Wireless Bridge
#                       </a>
#                      </h2>
#                      <!--<p><a href="https://www.commandonetworks.com/wireless/Wireless_Bridge_AirOne" target="_blank">AirONE</a></p>
# 									<p><a href="https://www.commandonetworks.com/wireless/Wireless_Bridge_AirNet" target="_blank">AirNET</a></p>
# 									<p><a href="https://www.commandonetworks.com/wireless/Wireless_Bridge_AirPro" target="_blank">AirPRO</a></p>-->
#                      <p>
#                       <a href="https://www.commandonetworks.com/wireless/Wireless_Bridge_24GHz80211n" target="_blank">
#                        2.4GHz 802.11n
#                       </a>
#                      </p>
#                      <p>
#                       <a href="https://www.commandonetworks.com/wireless/Wireless_Bridge_5GHz80211ac" target="_blank">
#                        5 GHz 802.11ac
#                       </a>
#                      </p>
#                      <p>
#                       <a href="https://www.commandonetworks.com/wireless/Wireless_Bridge" target="_blank">
#                        All Wireless Bridge
#                       </a>
#                      </p>
#                     </dd>
#                    </dl>
#                    <div class="clearfx">
#                    </div>
#                    <dl class="header_list_more_ul_main_all_con">
#                     <dt>
#                      <img src="https://www.commandonetworks.com/assets/img/home_category/wireless/antenna.png"/>
#                     </dt>
#                     <dd>
#                      <h2>
#                       <a href="https://www.commandonetworks.com/wireless/Antenna" target="_blank">
#                        Antenna
#                       </a>
#                      </h2>
#                      <!--<p><a href="https://www.commandonetworks.com/wireless/wallap_2_4GHz802_11n">2.4GHz 802.11n</a></p>
# 									<p><a href="https://www.commandonetworks.com/wireless/wallap_2_4GHzplus5GHz802_11ac">2.4GHz+5GHz 802.11ac</a></p>
# 									<p><a href="https://www.commandonetworks.com/wireless/wall_access_points">All Antenna</a></p>-->
#                     </dd>
#                    </dl>
#                    <dl class="header_list_more_ul_main_all_con">
#                     <dt>
#                      <img src="https://www.commandonetworks.com/assets/img/home_category/wireless/AirONE.png"/>
#                     </dt>
#                     <dd>
#                      <h2>
#                       <a href="https://www.commandonetworks.com/wireless/AirONE" target="_blank">
#                        AirONE
#                       </a>
#                      </h2>
#                      <p>
#                       <a href="https://www.commandonetworks.com/wireless/AirONE_Indoor_AP" target="_blank">
#                        Indoor AP
#                       </a>
#                      </p>
#                      <p>
#                       <a href="https://www.commandonetworks.com/wireless/AirONE_Outdoor_AP" target="_blank">
#                        Outdoor AP
#                       </a>
#                      </p>
#                      <p>
#                       <a href="https://www.commandonetworks.com/wireless/AirONE_Wireless_Bridge" target="_blank">
#                        Wireless Bridge
#                       </a>
#                      </p>
#                      <p>
#                       <a href="https://www.commandonetworks.com/wireless/AirONE" target="_blank">
#                        All AirONE
#                       </a>
#                      </p>
#                     </dd>
#                    </dl>
#                    <dl class="header_list_more_ul_main_all_con">
#                     <dt>
#                      <img src="https://www.commandonetworks.com/assets/img/home_category/wireless/AirNET.png"/>
#                     </dt>
#                     <dd>
#                      <h2>
#                       <a href="https://www.commandonetworks.com/wireless/AirNET" target="_blank">
#                        AirNET
#                       </a>
#                      </h2>
# ...
#            <a href="javascript:;">
#             <span>
#              RFQ
#             </span>
#             <i class="fal fa-plus">
#             </i>
#            </a>
#           </div>
#           <div class="m_footer_03_two">
#            <a href="https://www.commandonetworks.com/rfq/switches" target="_blank">
#             Switches
#            </a>
#            <!--<a href="https://www.commandonetworks.com/rfq/routers" target="_blank">Routers</a>-->
#            <a href="https://www.commandonetworks.com/rfq/wireless" target="_blank">
#             Wireless
#            </a>
#            <a href="https://www.commandonetworks.com/rfq/converters" target="_blank">
#             Media Converters
#            </a>
#            <a href="https://www.commandonetworks.com/rfq/transceivers" target="_blank">
#             Transceivers
#            </a>
#            <a href="https://www.commandonetworks.com/rfq/injectors" target="_blank">
#             PoE Injectors
#            </a>
#            <!--<a href="https://www.commandonetworks.com/rfq/networkingaccessories" target="_blank">Networking Accessories</a>-->
#           </div>
#          </div>
#         </div>
#        </div>
#        <div class="m_footer_share">
#         <a class="m_footer_share_icon" href="#" target="_blank" title="facebook">
#          <i class="fab fa-facebook-f">
#          </i>
#         </a>
#         <a class="m_footer_share_icon" href="#" target="_blank" title="twitter">
#          <i class="fab fa-twitter">
#          </i>
#         </a>
#         <a class="m_footer_share_icon" href="#" target="_blank" title="blog">
#          <i class="fal fa-blog">
#          </i>
#         </a>
#         <a class="m_footer_share_icon" href="#" target="_blank" title="google+">
#          <i class="fab fa-google-plus-g">
#          </i>
#         </a>
#         <a class="m_footer_share_icon" href="#" target="_blank" title="youtube">
#          <i class="fab fa-youtube">
#          </i>
#         </a>
#         <a class="m_footer_share_icon" href="#" target="_blank" title="COMMANDO APP">
#          <i class="fal fa-mobile-android">
#          </i>
#         </a>
#        </div>
#        <!--Copyright Desktop-->
#        <div class="copyright text-center">
#         <div class="container-fluid">
#          <div class="col-xl-12 footer_bottom">
#           <p class="pull-left">
#            Copyright © 2010-2020 COMMANDO Networks. All Rights Reserved.
#            <!--<a href="privacy-policy">Privacy Policy</a> | <a href="#">Terms and Condition</a> | <a href="#">Site Map</a></p>-->
#           </p>
#          </div>
#         </div>
#        </div>
#        <!--Copyright Mobile-->
#        <div class="footer_08">
#         <div>
#          Copyright © 2010-2020 COMMANDO Networks. All Rights Reserved.
#          <div class="footer_08_href">
#           <a href="https://www.commandonetworks.com/privacy-policy">
#            Privacy Policy
#           </a>
#           <span>
#            |
#           </span>
#           <!-- <a href="#">Terms and Condition</a> -->
#           <span>
#            |
#           </span>
#           <a href="https://www.commandonetworks.com/sitemap.xml">
#            Site Map
#           </a>
#          </div>
#         </div>
#        </div>
#       </footer>
#       <!--Footer Close-->
#      </section>
#     </div>
#     <!--Layout Close-->
#    </div>
#   </div>
#   <!--Off-Canvas Close-->
#   <!--Sticky Buttons-->
#   <div class="sticky-btns">
#    <span id="scrollTop-btn">
#     <i class="fal fa-chevron-up">
#     </i>
#    </span>
#   </div>
#   <!--Sticky Buttons Close-->
#   <!--Javascript (jQuery) Libraries and Plugins-->
#   <!-- <script src="https://www.commandonetworks.com/assets/js/libs/jquery-1.11.1.min.js"></script> -->
#   <!--<script src="https://ajax.googleapis.com/ajax/libs/jquery/3.4.1/jquery.min.js"></script>-->
#   <script src="https://www.commandonetworks.com/assets/js/libs/jquery.easing.min.js">
#   </script>
#   <script src="https://www.commandonetworks.com/assets/js/plugins/bootstrap.min.js">
#   </script>
#   <script src="https://www.commandonetworks.com/assets/js/plugins/bootstrap-datepicker.js">
#   </script>
#   <!--<script src="assets/js/plugins/smoothscroll.js"></script>-->
#   <script src="https://www.commandonetworks.com/assets/js/plugins/utilities.js">
#   </script>
#   <script src="https://www.commandonetworks.com/assets/js/plugins/foundation.min.js">
#   </script>
#   <script src="https://www.commandonetworks.com/assets/js/plugins/jquery.placeholder.js">
#   </script>
#   <script src="https://www.commandonetworks.com/assets/js/plugins/jquery.validate.min.js">
#   </script>
#   <script src="https://www.commandonetworks.com/assets/js/plugins/waypoints.min.js">
#   </script>
#   <script src="https://www.commandonetworks.com/assets/js/plugins/isotope.min.js">
#   </script>
#   <script src="https://www.commandonetworks.com/assets/js/plugins/masterslider.min.js">
#   </script>
#   <script src="https://www.commandonetworks.com/assets/js/plugins/owl.carousel.min.js">
#   </script>
#   <script src="https://www.commandonetworks.com/assets/js/plugins/lightGallery.min.js">
#   </script>
#   <script src="https://www.commandonetworks.com/assets/js/plugins/jquery.stellar.min.js">
#   </script>
#   <script src="https://www.commandonetworks.com/assets/js/plugins/jquery.parallax.min.js">
#   </script>
#   <!--<script src="https://www.commandonetworks.com/assets/js/plugins/chart.min.js"></script>-->
#   <script src="https://www.commandonetworks.com/assets/js/plugins/jquery-numerator.js">
#   </script>
#   <script src="https://www.commandonetworks.com/assets/js/plugins/jquery.countdown.min.js">
#   </script>
#   <!--<script src="https://www.commandonetworks.com/assets/js/plugins/jquery.easypiechart.min.js"></script>-->
#   <script src="https://www.commandonetworks.com/assets/js/plugins/jquery.nouislider.min.js">
#   </script>
#   <script src="https://www.commandonetworks.com/assets/js/plugins/card.min.js">
#   </script>
#   <script src="https://www.commandonetworks.com/assets/js/jquery.newsTicker.js">
#   </script>
#   <script src="https://www.commandonetworks.com/assets/js/swiper.min.js">
#   </script>
#   <script src="https://www.commandonetworks.com/assets/js/product-slider.js">
#   </script>
#   <script src="https://www.commandonetworks.com/assets/js/scripts.js">
#   </script>
#   <script src="https://www.commandonetworks.com/assets/js/scripts.min.js">
#   </script>
#   <script src="https://www.commandonetworks.com/assets/js/intlTelInput.js">
#   </script>
#   <script src="https://www.commandonetworks.com/assets/js/magnificpopup.min.js">
#   </script>
#   <script src="https://www.commandonetworks.com/assets/js/main.js">
#   </script>
#   <script src="https://www.commandonetworks.com/assets/js/header-with-menu.js" type="text/javascript">
#   </script>
#   <!--Day Nidht -->
#   <script src="https://www.commandonetworks.com/assets/js/daynightmode.js" type="text/javascript">
#   </script>
#   <script>
#    $("#mobile-number").intlTelInput();
#   $("#whatsapp-number").intlTelInput();
#   </script>
#   <!--<script type="text/javascript">
# /*Custom Style Checkboxes and Radios*/
# $('input').iCheck({
# 	checkboxClass: 'icheckbox',
# 	radioClass: 'iradio'
#   });
# </script>-->
#   <script>
#    /********* PRODUCT PAGE FILTERS **************/
# //Category Tab List Display, Count, Heading change
# var count = $(".cateTabCount .active .post").length;
# $('#countresult').text("Showing " + count + " results");
#
# $('#cateTab').on('change', function (e) {
#     $('.cateTabLi li a').eq($(this).val()).tab('show');
#
# 	var count = $(".cateTabCount .active .post").length;
# 	$('#countresult').text("Showing " + count + " results");
#
# 	var text = $(this).find('option:selected').text();
#     $('.tab-head').text(text);
# });
#
#
# // PARTNER APPLICATION STATE/CITY SELECT SCRIPT
#
# /********* CHANGE COUNTRY / STATE / CITY **************/
# $(".countries").change(function () {
#     var selected_country = $(this).val();
# 	var company_name = $("#cname").val();
# 	$.ajax({
# 		type:'POST',
# 		   url:'https://www.commandonetworks.com/partnercenter/ajax',
# 		data:'comp_name='+company_name+'&select_country='+selected_country+"&act=get_api",
# 		 success:function(html){
#                     $('#d_result').html(html);
#                     // $('#city').html('<option value="">Select state first</option>');
#                 }
#             });
#
#     // $("#isdcode").val($(this).find("option:selected").attr("data-value"))
#   });
#
# /*$(".countries").change(function () {
#     var selectedValue = $(this).val();
#     $("#country_code").val($(this).find("option:selected").attr("data-value"))
#   });*/
#
# $(document).ready(function(){
#     $(document).on('click','.countryList li', function() {
#         var countryID = $(this).text();
#         $("#country_hidden").val($(this).text());
#         if(countryID){
#             $.ajax({
#                 type:'POST',
#                 url:'https://www.commandonetworks.com/partnercenter/ajax',
#                 data:'country_id='+countryID,
#                 success:function(html){
#                     $('#state').html(html);
#                     $('#city').html('<li><a href="#">Select state first</a></li>');
#                 }
#             });
#         }else{
#             $('#state').html('<li><a href="#">Select country first</a></li>');
#             $('#city').html('<li><a href="#">Select state first</a></li>');
#         }
#     });
#
#      $(document).on('click','.stateList li', function() {
#         var stateID = $(this).text();
#         $("#state_hidden").val($(this).text());
#         if(stateID){
#             $.ajax({
#                 type:'POST',
#                 url:'https://www.commandonetworks.com/partnercenter/ajax',
#                 data:'state_id='+stateID,
#                 success:function(html){
#                     $('#city').html(html);
#                 }
#             });
#         }else{
#             $('#city').html('<li><a href="#">Select state first</a></li>');
#         }
#     });
# 	$(document).on('click','.cityList li', function() {
#         var cityID = $(this).text();
#         $("#city_hidden").val($(this).text());
#     });
# });
#
# //CONTACT PAGE SCRIPT
# $("#sendMail .countries").change(function () {
#     var selectedValue = $(this).val();
#     $("#country_codee").val($(this).find("option:selected").attr("data-value"))
# });
#
# setTimeout(function() {
# 	$('.alert').hide('fast');
# }, 10000);
#   </script>
#   <!--google captcha-->
#   <script src="https://www.google.com/recaptcha/api.js?onload=CaptchaCallback&amp;render=explicit&amp;hl=en">
#   </script>
#   <script type="text/javascript">
#    var CaptchaCallback = function(){
#
#       $('.g-recaptcha').each(function(){
#
#         grecaptcha.render(this,{'sitekey' : '6LeUFYAUAAAAAJldQk0pWZgRGtyapUlU2_-QeSnU'});
#
#       })
#
#       };
#   </script>
#   <!--//google captcha-->
#   <script type="text/javascript">
#    $('#form').on('submit', function(e) {
#
#   if(grecaptcha.getResponse() == "") {
#
#     e.preventDefault();
#
#     alert("Please verify google reCAPTCHA");
#
#   } else {
#
#     //alert("Thank you");
#
#   }
#
# });
#
#
#
# $('.carousel').carousel();
#   </script>
#   <!-- NEW MENU --
# <script type="text/javascript">
#   var iqitmegamenu = {"sticky":"false","mobileType":"push","containerSelector":"#wrapper .container"};
# </script>
# <script src="https://www.commandonetworks.com/assets/new-menu/menu_script.js"></script>
# <!-- NEW MENU END -->
#   <!--<script type='text/javascript' src='//platform-api.sharethis.com/js/sharethis.js#property=5c496f7980b4ba001b1ee82d&product=sop' async='async'></script>-->
#   <!-- Products Details Related products -->
#   <script src="https://www.commandonetworks.com/assets/product_related_slider/related_slider.js" type="text/javascript">
#   </script>
#   <script>
#    $('.one-time').slick({
#
#   dots: false,
#
#   slidesToShow: 5,
#
#   slidesToScroll: 1,
#
#   touchMove: true,
#
#   autoplay: true,
#
#   responsive: [
#
#     {
#
#       breakpoint: 1024,
#
#       settings: {
#
#         slidesToShow: 3,
#
#         slidesToScroll: 3,
#
#         infinite: true,
#
#         dots: false
#
#       }
#
#     },
#
#     {
#
#       breakpoint: 600,
#
#       settings: {
#
#         slidesToShow: 2,
#
#         slidesToScroll: 2
#
#       }
#
#     },
#
#     {
#
#       breakpoint: 480,
#
#       settings: {
#
#         slidesToShow: 1,
#
#         slidesToScroll: 1
#
#       }
#
#     }
#
#   ]
#
# });
#
#
#
# //CONTACT PAGE TAB
#
# $(document).ready(function() {
#
#     $("div.ftl-vertical-tab-menu>div.list-group>a").click(function(e) {
#
#         e.preventDefault();
#
#         $(this).siblings('a.active').removeClass("active");
#
#         $(this).addClass("active");
#
#         var index = $(this).index();
#
#         $("div.ftl-vertical-tab>div.ftl-vertical-tab-content").removeClass("active");
#
#         $("div.ftl-vertical-tab>div.ftl-vertical-tab-content").eq(index).addClass("active");
#
#     });
#
# });
#
# $('#datepicker').datepicker({
#
# 	weekStart: 1,
#
# 	daysOfWeekHighlighted: "6,0",
#
# 	autoclose: true,
#
# 	todayHighlight: true,
#
# });
#
# $('#datepicker').datepicker("setDate", new Date());
#
#
#
# //to show only 4 line text in products box
#
# $(".post p").text(function(index, currentText) {
#
#     return currentText.substr(0, 120);
#
# });
#
#
#
# //Mobile Menu Footer Box According
#
# (function($) {
#
#   var allPanels = $('.accordion > div > dd').hide();
#
#   $('.accordion > div > a > dt').click(function() {
#
#     allPanels.slideUp();
#
#     $(this).parent().next().slideDown();
#
#     return false;
#
#   });
#
# })(jQuery);
#
#
#
#
#
# $('.toggle').click(function(e) {
#
#   	e.preventDefault();
#
#
#
#     var $this = $(this);
#
#
#
#     if ($this.next().hasClass('show')) {
#
#         $this.next().removeClass('show');
#
#         $this.next().slideUp(350);
#
#     } else {
#
#         $this.parent().parent().find('li .inner').removeClass('show');
#
#         $this.parent().parent().find('li .inner').slideUp(350);
#
#         $this.next().toggleClass('show');
#
#         $this.next().slideToggle(350);
#
#     }
#
# });
#
# //Quotation country code selection
# $(".quotation #country_code").change(function () {
#     var selectedValue = $(this).val();
#     $("#pcode").val($(this).find("option:selected").attr("data-value"))
# });
#
# $(document).ready(function(){
#  $(".qnty_no").on("keyup", function () {
#   if ($(this).val() == 0) {
#   $(this).val(null);
#   }
# });
# });
#
# //Header Search - Without value submit will not work
# function hsValidate(){
#     /*if(document.getElementById('CityAjax').value == "")
# 	{
# 		alert("Enter some value");
# 		return false;
# 	}*/
# 	//var url = "http://stackoverflow.com";
# 	var base_url = 'https://www.commandonetworks.com/';
# 	if(document.getElementById('CityAjax').value == "")	{
# 		 window.location.href = base_url + "search";
# 		return false;
# 	}
# }
#   </script>
#   <!-- Quotation Sticky Sidebar -->
#   <script src="https://cdn.rawgit.com/leafo/sticky-kit/v1.1.2/jquery.sticky-kit.js">
#   </script>
#   <script>
#    $(document).ready(function(){
# 	$("#sidebar").stick_in_parent({ offset_top: 90 });
# });
#   </script>
#   <script>
#    //News Div Show and Hide if no LI will there
# if ( ! $(".bn-news li").length ){
#    $('.cmd_news_box').hide();
# }
#   </script>
#   <!--<script src="https://www.commandonetworks.com//smartbanner2/jquery.smartbanner.js"></script>-->
#   <script type="text/javascript">
#    //$(function() { $.smartbanner() } )
#
#   jQuery(function($) {
#   $(window).scroll(function fix_element() {
#     $('.smartbanner').css(
#       $(window).scrollTop() > 78
#         ? { 'position': 'fixed'}
#         : { 'position': 'absolute'}
#     );
#     return fix_element;
#   }());
# });
#   </script>
#   <!-- Whatsapp Widget -->
#   <script type="text/javascript">
#    /* <![CDATA[ */
# var tpw_settings = {"pluginUrl":"https:\/\/commandonetworks.com\/assets\/vendor\/whatsapp\/","intro_message":"Hi there 👋! <br/> How can i help you?","name":"COMMANDO Networks","link":"https:\/\/wa.me\/971509242643","status":"Online","button":"Start Chat","position":"left","profileImage":"https:\/\/commandonetworks.com\/assets\/vendor\/whatsapp\/profile_pic.jpg","windowHtml":"off","button_style":"https:\/\/commandonetworks.com\/assets\/vendor\/whatsapp\/green2-round.png"};
# /* ]]> */
#   </script>
#   <script src="https://www.commandonetworks.com/assets/vendor/whatsapp/widget.js">
#   </script>
#   <link href="https://www.commandonetworks.com/assets/vendor/whatsapp/widget.css" rel="stylesheet"/>
#   <!-- Whatsapp Widget end -->
#  </body>
#  <!--Body Close-->
# </html>

# %%
name=bsObj.find("h2",{"class":"post-title"})
print(name.get_text())
description =bsObj.find("div",{"class":"block-devider"})
print(description.get_text())
info =bsObj.find("div",{"class":"page-section hero"},{"id":"info"})
print(info.get_text())
specification =bsObj.findAll("tr")
for tag in specification:
    print(tag.get_text())
# Out:
# SF50-5
#
# COMMANDO SF50 5FE, SOHO Unmanaged Switch
#
#
#
# Information
# SF50-5 Fast Ethernet Switch is designed for SOHO (Small Office/Home Office) or workgroup users for the Ethernet access layer or aggregation layer, Plug and play, self-adaption, support standard, port isolation, simply plug and play.
# Auto features of SF50 series switch make installation plug and play and hassle-free. No configuring required. Auto MDI/MDIX eliminates the need for crossover cables. Auto-negotiation on each port senses the link speed of a network device (10, 100 Mbps) and intelligently adjusts for compatibility and optimal performance.
# SF50-5 forwards and filters packets at full wire-speed for maximum throughput. Featuring non-blocking switching architecture, with 10K Jumbo frame, the performance of large files transfers is improved significantly. And IEEE 802.3x flow control for Full Duplex mode and backpressure for Half Duplex mode alleviate the traffic congestion and make SF50-5 work reliably.
# Main Features
#
# Supports IEEE 802.3x flow control for Full Duplex mode and backpressure for Half Duplex mode
# Non-blocking switching architecture that forwards and filters packets at full wire-speed for maximum throughput
# All ports support wire speed switch, 10K jumbo frame transmission.
# Auto-negotiation ports provide smart integration between 10Mbps, 100Mbps and 1000Mbps hardware
# Supports MAC address auto-learning and auto-aging.
# Flood Control: Full-duplex: IEEE 802.3x, Half-duplex: back pressure.
# Auto MDI/MDIX.
# Store-and-Forward.
# Support camera, wireless AP, and IP phone etc
# Support port lightning protection.
# Plug and Play design simplifies installation.
# Fan less design ensures quiet operation
# Desktop or wall-mounting design
#
# Specification
#
# Hardware Features
# Interface5 10/100/M RJ45 Ports AUTO Negotiation/AUTO MDI/MDIX
# External Power Supply100~240VAC, 50/60Hz
# Software Features
# Transfer MethodStore and Forward
# Advanced FunctionsGreen Technology, saving power up to70% 802.3X Flow Control, Back Pressure Auto-Uplink Every Port
# Others
# Package Contents5-Port 10/100Mbps Desktop Switch Power Adapter User Guide
# Product specificationsOperating Temperature: 0°C~40°C (32°F~104°F) Storage Temperature: -40°C~70°C (-40°F~158°F) Operating Humidity: 10%~90% non-condensing Storage Humidity: 5%~90% non-condensing
